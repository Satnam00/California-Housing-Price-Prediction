# %%
import pandas as pd
import numpy as np
import random
from math import *
import operator
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline 

from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_squared_error, r2_score

import seaborn as sns
sns.set(style="white", color_codes=True)
from sklearn import datasets

# import the ML algorithm
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LinearRegression
from statsmodels.tools.eval_measures import rmse
import statsmodels.formula.api as smf
from sklearn.linear_model import LinearRegression

# pre-processing
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import scale
from sklearn.preprocessing import minmax_scale
from sklearn.preprocessing import MaxAbsScaler
from sklearn.preprocessing import RobustScaler
from sklearn.preprocessing import Normalizer
from sklearn.preprocessing.data import QuantileTransformer

# import libraries for model validation
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split

# import libraries for metrics and reporting
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score
from sklearn import metrics

import sklearn as sk
from sklearn import linear_model
from sklearn.neighbors import KNeighborsRegressor

import sklearn
sklearn.__version__

from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score

# import the ML algorithm
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LogisticRegression
from statsmodels.tools.eval_measures import rmse
from sklearn.naive_bayes import GaussianNB
from sklearn.naive_bayes import MultinomialNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import RandomForestRegressor
from sklearn.cluster import KMeans

# %%
location = r"F:/EducationalData/Simplilearn/ML/Files/datasets/housing.csv"

# %%
housing = pd.read_csv(location)
housing.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                  41          880           129.0
# 1    -122.22     37.86                  21         7099          1106.0
# 2    -122.24     37.85                  52         1467           190.0
# 3    -122.25     37.85                  52         1274           235.0
# 4    -122.25     37.85                  52         1627           280.0
#
#    population  households  median_income ocean_proximity  median_house_value
# 0         322         126         8.3252        NEAR BAY              452600
# 1        2401        1138         8.3014        NEAR BAY              358500
# 2         496         177         7.2574        NEAR BAY              352100
# 3         558         219         5.6431        NEAR BAY              341300
# 4         565         259         3.8462        NEAR BAY              342200

# %%
housing.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                  41          880           129.0
# 1    -122.22     37.86                  21         7099          1106.0
# 2    -122.24     37.85                  52         1467           190.0
# 3    -122.25     37.85                  52         1274           235.0
# 4    -122.25     37.85                  52         1627           280.0
#
#    population  households  median_income ocean_proximity  median_house_value
# 0         322         126         8.3252        NEAR BAY              452600
# 1        2401        1138         8.3014        NEAR BAY              358500
# 2         496         177         7.2574        NEAR BAY              352100
# 3         558         219         5.6431        NEAR BAY              341300
# 4         565         259         3.8462        NEAR BAY              342200

# %%
housing.dtypes
# Out:
# longitude             float64
# latitude              float64
# housing_median_age      int64
# total_rooms             int64
# total_bedrooms        float64
# population              int64
# households              int64
# median_income         float64
# ocean_proximity        object
# median_house_value      int64
# dtype: object

# %%
fig, axes = plt.subplots(ncols=8, figsize=(15, 5))

sns.boxplot(data=housing[['longitude']],  palette='Set2', ax=axes[0]);
sns.boxplot(data=housing[['latitude']],  palette='Set2', ax=axes[1]);
sns.boxplot(data=housing[['housing_median_age']],  palette='Set2', ax=axes[2]);
sns.boxplot(data=housing[['total_rooms']],  palette='Set2', ax=axes[3]);
sns.boxplot(data=housing[['total_bedrooms']],  palette='Set2', ax=axes[4]);
sns.boxplot(data=housing[['population']],  palette='Set2', ax=axes[5]);
sns.boxplot(data=housing[['households']],  palette='Set2', ax=axes[6]);
sns.boxplot(data=housing[['median_income']],  palette='Set2', ax=axes[7]);
# fig, axes = plt.subplots(ncols=8, figsize=(16, 5))
# n = 4

# sns.swarmplot(data=housing[['CRIM']],  palette='Set2', ax=axes[7], size=n);
#sns.boxplot(data=housing[['median_house_value']],  palette='Set2', ax=axes[9]);
# sns.boxplot(data=boston_df[['ZN']]  ,  palette='Set2', ax=axes[1]);
# sns.boxplot(data=boston_df[['INDUS']], palette='Set2', ax=axes[2]);
# sns.boxplot(data=boston_df[['CHAS']],  palette='Set2', ax=axes[3]);

# sns.boxplot(data=boston_df[['NOX']],   palette='Set2', ax=axes[4]);
# sns.boxplot(data=boston_df[['RM']]  ,  palette='Set2', ax=axes[5]);
# sns.boxplot(data=boston_df[['AGE']],   palette='Set2', ax=axes[6]);
# sns.boxplot(data=boston_df[['DIS']],   palette='Set2', ax=axes[7]);

# %%
# housing = housing[['longitude','latitude','housing_median_age','total_rooms','total_bedrooms','population','households','ocean_proximity','median_income']]

# %%
fig, axes = plt.subplots(ncols=8, figsize=(15, 5))

sns.boxplot(data=housing[['longitude']],  palette='Set2', ax=axes[0]);
sns.boxplot(data=housing[['latitude']],  palette='Set2', ax=axes[1]);
sns.boxplot(data=housing[['housing_median_age']],  palette='Set2', ax=axes[2]);
sns.boxplot(data=housing[['total_rooms']],  palette='Set2', ax=axes[3]);
sns.boxplot(data=housing[['total_bedrooms']],  palette='Set2', ax=axes[4]);
sns.boxplot(data=housing[['population']],  palette='Set2', ax=axes[5]);
sns.boxplot(data=housing[['households']],  palette='Set2', ax=axes[6]);
sns.boxplot(data=housing[['median_income']],  palette='Set2', ax=axes[7]);

# %%
# fig, axes = plt.subplots(ncols=2, figsize=(16, 5))
# n = 10

# fig, axes = plt.subplots(ncols=8, figsize=(15, 5))

# sns.swarmplot(data=housing[['longitude']],  palette='Set2', ax=axes[0]);
# sns.swarmplot(data=housing[['latitude']],  palette='Set2', ax=axes[1]);
# sns.swarmplot(data=housing[['housing_median_age']],  palette='Set2', ax=axes[2]);
# sns.swarmplot(data=housing[['total_rooms']],  palette='Set2', ax=axes[3]);
# sns.swarmplot(data=housing[['total_bedrooms']],  palette='Set2', ax=axes[4]);
# sns.swarmplot(data=housing[['population']],  palette='Set2', ax=axes[5]);
# sns.swarmplot(data=housing[['households']],  palette='Set2', ax=axes[6]);
# sns.swarmplot(data=housing[['median_income']],  palette='Set2', ax=axes[7]);

# %%
sns.pairplot(data=housing[['housing_median_age' , 'total_rooms' ,'total_bedrooms', 'population', 'households', 'median_income']], height=3);

# %%
housing.shape
# Out:
# (20640, 10)

# %%
from sklearn.preprocessing import LabelEncoder

# %%
housing['ocean_proximity'] = LabelEncoder().fit_transform(housing['ocean_proximity'])

# %%
housing['ocean_proximity'].value_counts()
# Out:
# 0    9136
# 1    6551
# 4    2658
# 3    2290
# 2       5
# Name: ocean_proximity, dtype: int64

# %% [markdown]
# # Removing null values with mean

# %%
housing.isnull().sum()
# Out:
# longitude               0
# latitude                0
# housing_median_age      0
# total_rooms             0
# total_bedrooms        207
# population              0
# households              0
# median_income           0
# ocean_proximity         0
# median_house_value      0
# dtype: int64

# %%
housing['total_bedrooms'].mean()
# Out:
# 537.8705525375618

# %%
housing['total_bedrooms'].fillna(housing['total_bedrooms'].mean(), inplace=True)

# %%
housing.isnull().sum()
# Out:
# longitude             0
# latitude              0
# housing_median_age    0
# total_rooms           0
# total_bedrooms        0
# population            0
# households            0
# median_income         0
# ocean_proximity       0
# median_house_value    0
# dtype: int64

# %%
housing.dtypes
# Out:
# longitude             float64
# latitude              float64
# housing_median_age      int64
# total_rooms             int64
# total_bedrooms        float64
# population              int64
# households              int64
# median_income         float64
# ocean_proximity         int32
# median_house_value      int64
# dtype: object

# %% [markdown]
# # Seprating features and labels

# %%
X = housing[['total_rooms','total_bedrooms','households','median_income','ocean_proximity']]
y = housing['median_house_value']

# %% [markdown]
# # Label Encoding Changing object into int

# %% [markdown]
# # Plotting

# %%
sns.pairplot(housing, 
             x_vars=['total_rooms', 'total_bedrooms', 'households', 'median_income'], 
             y_vars= 'median_house_value',
             size=7, 
             aspect=0.7, 
             kind='reg');
# Out:
# C:\Users\Satnam\Anaconda3\lib\site-packages\seaborn\axisgrid.py:2065: UserWarning: The `size` parameter has been renamed to `height`; pleaes update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# # MinMaxScaling

# %%
scaler = MinMaxScaler(feature_range=(0, 1))

scaler.fit(X)
# Out:
# C:\Users\Satnam\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:334: DataConversionWarning: Data with input dtype int32, int64, float64 were all converted to float64 by MinMaxScaler.
#   return self.partial_fit(X, y)
# MinMaxScaler(copy=True, feature_range=(0, 1))

# %%
rescaledX = scaler.transform(X)

# %%
colnames=['total_rooms', 'total_bedrooms', 'households', 'median_income', 'ocean_proximity']
X_scaled = pd.DataFrame(rescaledX, columns=colnames)
X_scaled.head()
# Out:
#    total_rooms  total_bedrooms  households  median_income  ocean_proximity
# 0     0.022331        0.019863    0.020556       0.539668             0.75
# 1     0.180503        0.171477    0.186976       0.538027             0.75
# 2     0.037260        0.029330    0.028943       0.466028             0.75
# 3     0.032352        0.036313    0.035849       0.354699             0.75
# 4     0.041330        0.043296    0.042427       0.230776             0.75

# %% [markdown]
# # Ploting before scaling and after scaling

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(14, 8))

ax1.set_title('Before Standarrising')
# sns.kdeplot(X['longitude'], ax=ax1)
# sns.kdeplot(X['latitude'], ax=ax1)
# sns.kdeplot(X['housing_median_age'], ax=ax1)
sns.kdeplot(X['total_rooms'], ax=ax1)
sns.kdeplot(X['total_bedrooms'], ax=ax1)
# sns.kdeplot(X['population'], ax=ax1)
sns.kdeplot(X['households'], ax=ax1)
sns.kdeplot(X['median_income'], ax=ax1)
sns.kdeplot(X['ocean_proximity'], ax=ax1)



ax2.set_title('After Standarrising')
# sns.kdeplot(X_scaled['longitude'], ax=ax2)
# sns.kdeplot(X_scaled['latitude'], ax=ax2)
# sns.kdeplot(X_scaled['housing_median_age'], ax=ax2)
sns.kdeplot(X_scaled['total_rooms'], ax=ax2)
sns.kdeplot(X_scaled['total_bedrooms'], ax=ax2)
# sns.kdeplot(X_scaled['population'], ax=ax2)
sns.kdeplot(X_scaled['households'], ax=ax2)
sns.kdeplot(X_scaled['median_income'], ax=ax2)
sns.kdeplot(X_scaled['ocean_proximity'], ax=ax2)

# %% [markdown]
# # Train Text Split

# %%
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.4, random_state=0)

# %%
print(X_train.shape, y_train.shape, X_test.shape, y_test.shape)
# Out:
# (12384, 5) (12384,) (8256, 5) (8256,)

# %%
#plt.scatter(X_train[:,5],y_train,c='red')
#plt.show()

# %%
#sns.pairplot(data=X_train, hue='class', size=3)

# %% [markdown]
# # LinearRegression

# %%
# from sklearn import linear_model
# import sklearn as sk
# algo = linear_model.LinearRegression()
# algo.fit (X_train, y_train)
# pred_y = algo.predict(X_test)

# MSE = sk.metrics.mean_squared_error(y_test, pred_y)
# print ("MSE for housing dataset using linear regression is" , MSE)
# print("Final rmse value is =",np.sqrt(np.mean((y_test-pred_y)**2)))

# instantiate
linreg = LinearRegression()

# fit the model to the training data (learn the coefficients)
linreg.fit(X_test, y_test)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
# print the coefficients
print(linreg.intercept_)
print(linreg.coef_)
# Out:
# 24964.135781333025
# [-1190185.64334488   556133.08454451   528920.40381541   697139.16838904
#     31540.35262022]

# %%
# pair the feature names with the coefficients
list(zip(colnames, linreg.coef_))
# Out:
# [('total_rooms', -1190185.6433448847),
#  ('total_bedrooms', 556133.0845445141),
#  ('households', 528920.4038154077),
#  ('median_income', 697139.1683890438),
#  ('ocean_proximity', 31540.352620224243)]

# %%
# Making predictions
# make predictions on the testing set
y_pred = linreg.predict(X_test)

# %%
# create a fitted model with all  features
sm_model = smf.ols(formula='median_house_value ~ total_rooms + total_bedrooms + households + median_income + ocean_proximity', 
                   data=housing).fit()

# %%
sm_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:     median_house_value   R-squared:                       0.516
# Model:                            OLS   Adj. R-squared:                  0.516
# Method:                 Least Squares   F-statistic:                     4393.
# Date:                Sat, 18 Jan 2020   Prob (F-statistic):               0.00
# Time:                        01:49:15   Log-Likelihood:            -2.6239e+05
# No. Observations:               20640   AIC:                         5.248e+05
# Df Residuals:                   20634   BIC:                         5.248e+05
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# ...

# %%
### STATSMODELS

# print the R-squared value for the model
sm_model.rsquared
# Out:
# 0.5156309892374373

# %%
# Model evaluation metrics for regression

print('Mean Abs Error   MAE    : ', metrics.mean_absolute_error(y_test, y_pred))
print('Mean Sq  Error MSE      : ', metrics.mean_squared_error(y_test, y_pred))
print('Root Mean Sq Error RMSE : ', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
print('r2 value                : ', metrics.r2_score(y_test, y_pred))
# Out:
# Mean Abs Error   MAE    :  59382.66194271995
# Mean Sq  Error MSE      :  6525957895.43617
# Root Mean Sq Error RMSE :  80783.40111332382
# r2 value                :  0.5106243347481718

# %%
algo = linear_model.LinearRegression()
algo.fit (X_train, y_train)
predictions = algo.predict(X_test)

MSE = sk.metrics.mean_squared_error(y_test, predictions)
RMSE = np.sqrt(sk.metrics.mean_squared_error(y_test, predictions))

print ("MSE for CA Housing dataset using linear regression is" , MSE)
print ("RMSE for CA Housing dataset using linear regression is" , RMSE)
# Out:
# MSE for CA Housing dataset using linear regression is 6548762800.979804
# RMSE for CA Housing dataset using linear regression is 80924.42647915278

# %% [markdown]
# # Decision Tree Regression

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=0)

# %%
from sklearn import model_selection
from sklearn.metrics import classification_report
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score

from sklearn.tree import DecisionTreeRegressor

# %%
algo = DecisionTreeRegressor()

# %%
algo.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor(criterion='mse', max_depth=None, max_features=None,
#            max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            presort=False, random_state=None, splitter='best')

# %%
y_pred = algo.predict(X_test)
y_pred

# plt.scatter(X_train[:,7],y_train,c='red')
# plt.show()
# plt.plot(X_test,pred_y)   
# plt.scatter(X_test,pred_y,c='red')
# plt.xlabel('headsize')
# plt.ylabel('brain weight')
# Out:
# array([377300., 235900., 124900., ..., 405800., 186000., 102200.])

# %%
# algo.score(X_test, y_test)

# %%
algo.fit (X_train, y_train)
pred_y = algo.predict(X_test)

MSE = sk.metrics.mean_squared_error(y_test, pred_y)
print ("MSE for housing dataset using linear regression is" , MSE)
print("Final rmse value is =",np.sqrt(np.mean((y_test-pred_y)**2)))
# Out:
# MSE for housing dataset using linear regression is 10083535392.766352
# Final rmse value is = 100416.80831796215

# %%
y_pred = algo.predict(X_test) 
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# Root Mean Squared Error: 100416.80831796215

# %%
# MSE = sk.metrics.mean_squared_error(y_test, pred_y)
# print ("MSE for housing dataset using linear regression is" , MSE)
# print("Final rmse value is =",np.sqrt(np.mean((y_test-pred_y)**2)))

# %% [markdown]
# # Random Forest

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state =4)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import RandomForestRegressor
clf = RandomForestRegressor(random_state=4)

# %%
 clf.fit(X_train, y_train)
# Out:
# C:\Users\Satnam\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=None,
#            oob_score=False, random_state=4, verbose=0, warm_start=False)

# %%
importances = list(clf.feature_importances_)
importances
# Out:
# [0.10595576523280292,
#  0.09134962139570577,
#  0.08274658269636048,
#  0.5899331761327565,
#  0.13001485454237433]

# %%
feature_importances = [(feature, round(importance, 2)) for feature, importance in zip(X_train.columns, importances)]
feature_importances
# Out:
# [('total_rooms', 0.11),
#  ('total_bedrooms', 0.09),
#  ('households', 0.08),
#  ('median_income', 0.59),
#  ('ocean_proximity', 0.13)]

# %%
importances = sorted(feature_importances, key = lambda x: x[1], reverse = True)
importances
# Out:
# [('median_income', 0.59),
#  ('ocean_proximity', 0.13),
#  ('total_rooms', 0.11),
#  ('total_bedrooms', 0.09),
#  ('households', 0.08)]

# %%
# Make predictions and determine the error
predictions = clf.predict(X_test)
errors = abs(predictions - y_test)
# Display the performance metrics
print('Mean Absolute Error:', round(np.mean(errors), 2), 'degrees.')
# The root mean squared error
print("Root Mean squared error: %.2f"% np.sqrt(mean_squared_error(y_test, predictions)))
mape = np.mean(100 * (errors / y_test))

accuracy = 100 - mape
print('Accuracy:', round(accuracy, 2), '%.')
# Out:
# Mean Absolute Error: 54580.03 degrees.
# Root Mean squared error: 76542.27
# Accuracy: 70.03 %.

# %% [markdown]
# # Linear Regression with one independent veriable Median Income vs Median House Value

# %%
#LearnRegrationho
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LinearRegression

# %%
#X = housing[['median_income', 'total_rooms', 'population']]
X = housing[['median_income']]
y = housing['median_house_value']

# %%
sns.pairplot(housing, 
             x_vars=['median_income'], 
             y_vars= 'median_house_value',
             size=7, 
             aspect=0.7, 
             kind='reg');
# Out:
# C:\Users\Satnam\Anaconda3\lib\site-packages\seaborn\axisgrid.py:2065: UserWarning: The `size` parameter has been renamed to `height`; pleaes update your code.
#   warnings.warn(msg, UserWarning)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state =4)

# %%
# instantiate
linreg = LinearRegression()

# fit the model to the training data (learn the coefficients)
linreg.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
# print the coefficients
print(linreg.intercept_)
print(linreg.coef_)
# Out:
# 44893.29799892893
# [41806.86300219]

# %%
# pair the feature names with the coefficients
list(zip(['median_income'], linreg.coef_))
# Out:
# [('median_income', 41806.863002192535)]

# %%
# Making predictions
# make predictions on the testing set
y_pred = linreg.predict(X_test)

# %%
# create a fitted model with all  features
sm_model = smf.ols(formula='median_house_value ~  median_income', 
                   data=housing).fit()

# %%
### STATSMODELS ###

# print a summary of the fitted model
sm_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:     median_house_value   R-squared:                       0.473
# Model:                            OLS   Adj. R-squared:                  0.473
# Method:                 Least Squares   F-statistic:                 1.856e+04
# Date:                Sat, 18 Jan 2020   Prob (F-statistic):               0.00
# Time:                        01:49:52   Log-Likelihood:            -2.6325e+05
# No. Observations:               20640   AIC:                         5.265e+05
# Df Residuals:                   20638   BIC:                         5.265e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# ...

# %%
### STATSMODELS

# print the R-squared value for the model
sm_model.rsquared
# Out:
# 0.47344749180719914

# %%
# Model evaluation metrics for regression

print('Mean Abs Error   MAE    : ', metrics.mean_absolute_error(y_test, y_pred))
print('Mean Sq  Error MSE      : ', metrics.mean_squared_error(y_test, y_pred))
print('Root Mean Sq Error RMSE : ', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
print('r2 value                : ', metrics.r2_score(y_test, y_pred))
# Out:
# Mean Abs Error   MAE    :  62250.94442933963
# Mean Sq  Error MSE      :  7000047665.036318
# Root Mean Sq Error RMSE :  83666.287505998
# r2 value                :  0.4653014753128556

# %%
algo.fit (X_train, y_train)
predictions = algo.predict(X_test)

MSE = sk.metrics.mean_squared_error(y_test, predictions)
RMSE = np.sqrt(sk.metrics.mean_squared_error(y_test, predictions))

print ("MSE for CA Housing dataset using linear regression is" , MSE)
print ("RMSE for CA Housing dataset using linear regression is" , RMSE)
# Out:
# MSE for CA Housing dataset using linear regression is 11522853444.141344
# RMSE for CA Housing dataset using linear regression is 107344.55479502137
